# %%
#1.Identify and fix the syntax error in the following code:


age = 18
if age >= 18
    print("You are eligible to vote")

# %%
#1. Syntax error
age = 18
if age >= 18:
    print("You are eligible to vote")
# Out:
# You are eligible to vote

# %%
#2.Question:
What error will occur in the following code?


def greet():
    print("Hello, World!")

greet_user()

# %%
#2. Incorrect function name
def greet():
    print("Hello, World!")

greet()
# Out:
# Hello, World!

# %%
#3.Identify the error in this code:

name = "Alice"
age = 25
print("My name is " + name + " and I am " + age + " years old.")

# %%
#3.
name = "Alice"
age = 25
print("My name is " + "(name)" + " and I am " + "(age)" + " years old.")
# Out:
# My name is (name) and I am (age) years old.

# %%
#4.Question:
What will happen when you run this code?

a = 10
b = 0
result = a / b
print(result)

# %%
#4. the number cannot be divided by 0
a = 10
b = 1
result = a / b
print(result)
# Out:
# 10.0

# %%
#5.What error will occur in the following code?

num = int("xyz")
print(num)

# %%
#5.int value chould be numerical
num = int("10")
print(num)
# Out:
# 10

# %%
#6.Identify the issue in this code:

data = {"name": "John", "age": 30}
print(data["city"])

# %%
#6. The city name is not included
data = {"name": "John", "age": 30}
print(data["name"])

data = {"name": "John", "age": 30, "city": "Chennai"}
print(data["city"])
# Out:
# John
# Chennai

# %%
#7.What will happen when you run this code?
num = 1
while num < 5:
    print(num)

# %%
#8.What is wrong with this code?

fruits = ("apple", "banana", "cherry")
print(fruits[3])

# %%
#8. this will not print the third value
fruits = ("apple", "banana", "cherry")
print(fruits[2])

# %%
#9.What will happen when you run this code?

text = "hello world"
text.append("!")

# %%
#9. this will append the special character
text = "hello world"
text.append("!")

# %%
#10.What is wrong with the following code?

import randoms
print(randoms.randint(1, 10))

# %%
import randoms
print(randoms.randint(1, 10))
